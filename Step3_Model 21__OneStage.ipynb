# %% [markdown]
# ### 馬達論文研究
# ### 第三步 遷移式學習
# ### 馬達A 8000RPM
# ### CNN_VGG
# ### 單階段泛化

# %%
# 匯入所需函式庫
import os
import logging
import absl.logging
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler, label_binarize, LabelEncoder, RobustScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, Input, Concatenate, Add, Activation, GlobalAveragePooling1D, Multiply
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings("ignore")

# %%
# 資料準備與處理
def load_and_preprocess_data(base_dir, screws_list):
    datasets = []
    for screws in screws_list:
        file_path = os.path.join(base_dir, f'T3\\8000rpm\\{screws}\\T3_Group_feature_data.csv')
        if os.path.exists(file_path):
            dataset = pd.read_csv(file_path)
            dataset['screws'] = screws
            datasets.append(dataset)
        else:
            print(f"檔案未找到: {file_path}")
    return datasets

# %%
# 加載資料
rootDir = os.getcwd()
modelDirectory = f'{rootDir}\\階段1\\model'
myfeatureDirectory = f'{rootDir}\\階段3\\myfeature'

screws_list = ['8screws', '1screws', '2screws', '3screws', '4screws']
datasets_T1 = load_and_preprocess_data(myfeatureDirectory, screws_list)

# %%
# 合併資料
combined_data = pd.concat(datasets_T1, ignore_index=True)

# %%
# **手動定義標籤順序**
desired_order = ['8screws', '1screws', '2screws', '3screws', '4screws']
label_mapping = {screw: idx for idx, screw in enumerate(desired_order)}
combined_data['screws'] = combined_data['screws'].map(label_mapping)

# %%
# 標籤編碼
le_screws = LabelEncoder()
combined_data['screws'] = le_screws.fit_transform(combined_data['screws'])

# %%
# 確認標籤映射是否正確
print("自訂 Label Mapping:")
for label, num in label_mapping.items():
    print(f"{label}: {num}")
# Out:
# 自訂 Label Mapping:
# 8screws: 0
# 1screws: 1
# 2screws: 2
# 3screws: 3
# 4screws: 4

# %%
# 資料分割
X = combined_data.drop(['screws'], axis=1).values
y_screws = combined_data['screws'].values

# %%
# 劃分訓練與測試集
X_train, X_test, y_train_screws, y_test_screws = train_test_split(
    X, y_screws, test_size=0.2, random_state=42
)

# %%
# 標準化特徵
scaler = RobustScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# 載入模型
model_path = f'{modelDirectory}\\VGG16_C8000.keras'

# 載入模型
model = load_model(model_path)

# 確認模型載入成功
print("模型已成功載入。")
# Out:
# 模型已成功載入。

# %%
# 計算需要凍結的層數（保留 50% 可訓練）
num_layers = len(model.layers)
train_layers_1 = int(num_layers * 0.5)  # 50% 可訓練
freeze_layers_1 = num_layers - train_layers_1  # 50% 凍結

# 凍結前 freeze_layers層
for layer in model.layers[:freeze_layers_1]:
    layer.trainable = False

# 確認層狀態
for i, layer in enumerate(model.layers):
    print(f"Model 2 - Layer {i}: {layer.name} | Trainable: {layer.trainable}")
# Out:
# Model 2 - Layer 0: input_layer | Trainable: False
# Model 2 - Layer 1: conv1d | Trainable: False
# Model 2 - Layer 2: conv1d_1 | Trainable: False
# Model 2 - Layer 3: max_pooling1d | Trainable: False
# Model 2 - Layer 4: conv1d_2 | Trainable: False
# Model 2 - Layer 5: conv1d_3 | Trainable: False
# Model 2 - Layer 6: max_pooling1d_1 | Trainable: False
# Model 2 - Layer 7: conv1d_4 | Trainable: False
# Model 2 - Layer 8: conv1d_5 | Trainable: False
# Model 2 - Layer 9: conv1d_6 | Trainable: False
# Model 2 - Layer 10: max_pooling1d_2 | Trainable: False
# Model 2 - Layer 11: conv1d_7 | Trainable: False
# Model 2 - Layer 12: conv1d_8 | Trainable: False
# Model 2 - Layer 13: conv1d_9 | Trainable: True
# Model 2 - Layer 14: max_pooling1d_3 | Trainable: True
# Model 2 - Layer 15: conv1d_10 | Trainable: True
# Model 2 - Layer 16: conv1d_11 | Trainable: True
# Model 2 - Layer 17: conv1d_12 | Trainable: True
# Model 2 - Layer 18: max_pooling1d_4 | Trainable: True
# Model 2 - Layer 19: flatten | Trainable: True
# Model 2 - Layer 20: dense | Trainable: True
# Model 2 - Layer 21: dropout | Trainable: True
# Model 2 - Layer 22: dense_1 | Trainable: True
# Model 2 - Layer 23: dropout_1 | Trainable: True
# Model 2 - Layer 24: Screw_Number_Output | Trainable: True

# %%
# 重新訓練模型
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=["sparse_categorical_crossentropy"],
    metrics=["accuracy"]
)

# %%
# 訓練模型
history = model.fit(
    X_train.reshape(X_train.shape[0], X_train.shape[1], 1),
    y_train_screws,
    validation_data=(
        X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
        y_test_screws
    ),
    epochs=100,
    batch_size=32,
    callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
)
# Out:
# Epoch 1/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3356 - loss: 3.5559 - val_accuracy: 0.3506 - val_loss: 1.5097
# Epoch 2/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3607 - loss: 1.4953 - val_accuracy: 0.3856 - val_loss: 1.3360
# Epoch 3/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3955 - loss: 1.3290 - val_accuracy: 0.4491 - val_loss: 1.2309
# Epoch 4/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4451 - loss: 1.2783 - val_accuracy: 0.4875 - val_loss: 1.1496
# Epoch 5/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4699 - loss: 1.2220 - val_accuracy: 0.5309 - val_loss: 1.0940
# Epoch 6/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4851 - loss: 1.2030 - val_accuracy: 0.5426 - val_loss: 1.0665
# Epoch 7/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4870 - loss: 1.1827 - val_accuracy: 0.5593 - val_loss: 1.0275
# Epoch 8/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4956 - loss: 1.1600 - val_accuracy: 0.5943 - val_loss: 0.9767
# Epoch 9/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5112 - loss: 1.1344 - val_accuracy: 0.6177 - val_loss: 0.9395
# Epoch 10/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5064 - loss: 1.1189 - val_accuracy: 0.6394 - val_loss: 0.9017
# Epoch 11/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5244 - loss: 1.1005 - val_accuracy: 0.6528 - val_loss: 0.8859
# Epoch 12/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5475 - loss: 1.0669 - val_accuracy: 0.6528 - val_loss: 0.8921
# Epoch 13/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5581 - loss: 1.0346 - val_accuracy: 0.6661 - val_loss: 0.8520
# Epoch 14/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5671 - loss: 1.0208 - val_accuracy: 0.6694 - val_loss: 0.8331
# Epoch 15/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5408 - loss: 1.0433 - val_accuracy: 0.6795 - val_loss: 0.8168
# Epoch 16/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5548 - loss: 1.0259 - val_accuracy: 0.6845 - val_loss: 0.8097
# Epoch 17/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5583 - loss: 1.0191 - val_accuracy: 0.6912 - val_loss: 0.7990
# Epoch 18/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5911 - loss: 0.9694 - val_accuracy: 0.6962 - val_loss: 0.7976
# Epoch 19/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5761 - loss: 1.0016 - val_accuracy: 0.7112 - val_loss: 0.7814
# Epoch 20/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5750 - loss: 0.9772 - val_accuracy: 0.7229 - val_loss: 0.7688
# Epoch 21/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5623 - loss: 0.9973 - val_accuracy: 0.7262 - val_loss: 0.7594
# Epoch 22/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5691 - loss: 0.9774 - val_accuracy: 0.7279 - val_loss: 0.7585
# Epoch 23/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5993 - loss: 0.9451 - val_accuracy: 0.7379 - val_loss: 0.7522
# Epoch 24/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5954 - loss: 0.9577 - val_accuracy: 0.7362 - val_loss: 0.7410
# Epoch 25/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5855 - loss: 0.9393 - val_accuracy: 0.7496 - val_loss: 0.7235
# Epoch 26/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5858 - loss: 0.9421 - val_accuracy: 0.7529 - val_loss: 0.7216
# Epoch 27/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6067 - loss: 0.9227 - val_accuracy: 0.7479 - val_loss: 0.7391
# Epoch 28/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6192 - loss: 0.9120 - val_accuracy: 0.7646 - val_loss: 0.6992
# Epoch 29/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6032 - loss: 0.9342 - val_accuracy: 0.7713 - val_loss: 0.7028
# Epoch 30/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5997 - loss: 0.9379 - val_accuracy: 0.7713 - val_loss: 0.6777
# Epoch 31/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6123 - loss: 0.8975 - val_accuracy: 0.7746 - val_loss: 0.6719
# Epoch 32/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6223 - loss: 0.8684 - val_accuracy: 0.7880 - val_loss: 0.6793
# Epoch 33/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6316 - loss: 0.8538 - val_accuracy: 0.7896 - val_loss: 0.6650
# Epoch 34/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6031 - loss: 0.9131 - val_accuracy: 0.7963 - val_loss: 0.6471
# Epoch 35/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6115 - loss: 0.8828 - val_accuracy: 0.7846 - val_loss: 0.6349
# Epoch 36/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6024 - loss: 0.9077 - val_accuracy: 0.8013 - val_loss: 0.6323
# Epoch 37/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6190 - loss: 0.8839 - val_accuracy: 0.7913 - val_loss: 0.6488
# Epoch 38/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6476 - loss: 0.8652 - val_accuracy: 0.8047 - val_loss: 0.6266
# Epoch 39/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6540 - loss: 0.8425 - val_accuracy: 0.7980 - val_loss: 0.6116
# Epoch 40/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6504 - loss: 0.8531 - val_accuracy: 0.8013 - val_loss: 0.6021
# Epoch 41/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6433 - loss: 0.8285 - val_accuracy: 0.8063 - val_loss: 0.5945
# Epoch 42/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6112 - loss: 0.8632 - val_accuracy: 0.8114 - val_loss: 0.5870
# Epoch 43/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6447 - loss: 0.8294 - val_accuracy: 0.8164 - val_loss: 0.5665
# Epoch 44/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6432 - loss: 0.8379 - val_accuracy: 0.8297 - val_loss: 0.5428
# Epoch 45/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6481 - loss: 0.8308 - val_accuracy: 0.8698 - val_loss: 0.4805
# Epoch 46/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6721 - loss: 0.8055 - val_accuracy: 0.8965 - val_loss: 0.4594
# Epoch 47/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7312 - loss: 0.7260 - val_accuracy: 0.8831 - val_loss: 0.4152
# Epoch 48/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7258 - loss: 0.7152 - val_accuracy: 0.8865 - val_loss: 0.3886
# Epoch 49/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7414 - loss: 0.6633 - val_accuracy: 0.9082 - val_loss: 0.3900
# Epoch 50/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7355 - loss: 0.6858 - val_accuracy: 0.9165 - val_loss: 0.3636
# Epoch 51/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7547 - loss: 0.6442 - val_accuracy: 0.9416 - val_loss: 0.3361
# Epoch 52/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7461 - loss: 0.6311 - val_accuracy: 0.9382 - val_loss: 0.3315
# Epoch 53/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7672 - loss: 0.6272 - val_accuracy: 0.9399 - val_loss: 0.3197
# Epoch 54/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7904 - loss: 0.5912 - val_accuracy: 0.9482 - val_loss: 0.3029
# Epoch 55/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7674 - loss: 0.5962 - val_accuracy: 0.9499 - val_loss: 0.3076
# Epoch 56/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7755 - loss: 0.6163 - val_accuracy: 0.9666 - val_loss: 0.2884
# Epoch 57/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7933 - loss: 0.5655 - val_accuracy: 0.9583 - val_loss: 0.2754
# Epoch 58/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7789 - loss: 0.5782 - val_accuracy: 0.9666 - val_loss: 0.2715
# Epoch 59/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7617 - loss: 0.6145 - val_accuracy: 0.9649 - val_loss: 0.2724
# Epoch 60/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8028 - loss: 0.5602 - val_accuracy: 0.9649 - val_loss: 0.2586
# Epoch 61/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7948 - loss: 0.5509 - val_accuracy: 0.9616 - val_loss: 0.2549
# Epoch 62/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8033 - loss: 0.5549 - val_accuracy: 0.9649 - val_loss: 0.2467
# Epoch 63/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7984 - loss: 0.5369 - val_accuracy: 0.9699 - val_loss: 0.2556
# Epoch 64/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7954 - loss: 0.5595 - val_accuracy: 0.9733 - val_loss: 0.2382
# Epoch 65/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8111 - loss: 0.5290 - val_accuracy: 0.9750 - val_loss: 0.2318
# Epoch 66/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7974 - loss: 0.5467 - val_accuracy: 0.9733 - val_loss: 0.2302
# Epoch 67/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8328 - loss: 0.4977 - val_accuracy: 0.9633 - val_loss: 0.2327
# Epoch 68/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8046 - loss: 0.5605 - val_accuracy: 0.9783 - val_loss: 0.2180
# Epoch 69/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8073 - loss: 0.5206 - val_accuracy: 0.9766 - val_loss: 0.2263
# Epoch 70/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7986 - loss: 0.5421 - val_accuracy: 0.9800 - val_loss: 0.2163
# Epoch 71/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8421 - loss: 0.4892 - val_accuracy: 0.9666 - val_loss: 0.2155
# Epoch 72/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8264 - loss: 0.4962 - val_accuracy: 0.9800 - val_loss: 0.2004
# Epoch 73/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8273 - loss: 0.4962 - val_accuracy: 0.9816 - val_loss: 0.1918
# Epoch 74/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8437 - loss: 0.5205 - val_accuracy: 0.9833 - val_loss: 0.1895
# Epoch 75/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8571 - loss: 0.4625 - val_accuracy: 0.9900 - val_loss: 0.1889
# Epoch 76/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8311 - loss: 0.5006 - val_accuracy: 0.9816 - val_loss: 0.1896
# Epoch 77/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8478 - loss: 0.4664 - val_accuracy: 0.9800 - val_loss: 0.1840
# Epoch 78/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8568 - loss: 0.4433 - val_accuracy: 0.9850 - val_loss: 0.1932
# Epoch 79/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8536 - loss: 0.4723 - val_accuracy: 0.9816 - val_loss: 0.1780
# Epoch 80/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8592 - loss: 0.4567 - val_accuracy: 0.9816 - val_loss: 0.1744
# Epoch 81/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8594 - loss: 0.4602 - val_accuracy: 0.9833 - val_loss: 0.1778
# Epoch 82/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8501 - loss: 0.4568 - val_accuracy: 0.9816 - val_loss: 0.1709
# Epoch 83/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8594 - loss: 0.4646 - val_accuracy: 0.9766 - val_loss: 0.1783
# Epoch 84/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8589 - loss: 0.4564 - val_accuracy: 0.9783 - val_loss: 0.1710
# Epoch 85/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8536 - loss: 0.4494 - val_accuracy: 0.9850 - val_loss: 0.1704
# Epoch 86/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8632 - loss: 0.4342 - val_accuracy: 0.9850 - val_loss: 0.1674
# Epoch 87/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8734 - loss: 0.4252 - val_accuracy: 0.9800 - val_loss: 0.1736
# Epoch 88/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8715 - loss: 0.4228 - val_accuracy: 0.9850 - val_loss: 0.1559
# Epoch 89/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8857 - loss: 0.4011 - val_accuracy: 0.9816 - val_loss: 0.1563
# Epoch 90/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8810 - loss: 0.3891 - val_accuracy: 0.9850 - val_loss: 0.1502
# Epoch 91/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8730 - loss: 0.4088 - val_accuracy: 0.9883 - val_loss: 0.1499
# Epoch 92/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8836 - loss: 0.4033 - val_accuracy: 0.9850 - val_loss: 0.1486
# Epoch 93/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9010 - loss: 0.3513 - val_accuracy: 0.9866 - val_loss: 0.1449
# Epoch 94/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8954 - loss: 0.3770 - val_accuracy: 0.9866 - val_loss: 0.1445
# Epoch 95/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9037 - loss: 0.3580 - val_accuracy: 0.9900 - val_loss: 0.1427
# Epoch 96/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8783 - loss: 0.4063 - val_accuracy: 0.9866 - val_loss: 0.1399
# Epoch 97/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9141 - loss: 0.3307 - val_accuracy: 0.9866 - val_loss: 0.1373
# Epoch 98/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9020 - loss: 0.3485 - val_accuracy: 0.9883 - val_loss: 0.1385
# Epoch 99/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9032 - loss: 0.3715 - val_accuracy: 0.9883 - val_loss: 0.1363
# Epoch 100/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8948 - loss: 0.3746 - val_accuracy: 0.9850 - val_loss: 0.1400

# %%
# 清除
tf.keras.backend.clear_session()
# Out:
# WARNING:tensorflow:From c:\Users\IMSL\anaconda3\envs\motor\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
# 模型架構
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 105, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 105, 16)        │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 105, 16)        │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 52, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 52, 16)         │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 52, 16)         │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 26, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 26, 16)         │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 26, 16)         │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 26, 16)         │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 13, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 13, 16)         │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 13, 16)         │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 13, 16)         │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 6, 16)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 6, 16)          │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 6, 16)          │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_12 (Conv1D)              │ (None, 6, 16)          │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 3, 16)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 48)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Screw_Number_Output (Dense)     │ (None, 5)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,169 (74.88 KB)
#  Trainable params: 4,277 (16.71 KB)
#  Non-trainable params: 6,336 (24.75 KB)
#  Optimizer params: 8,556 (33.43 KB)

# %%
# 評估模型
results = model.evaluate(
    X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
    y_test_screws
)
print(f"Loss: {results[0]:.4f}, Accuracy: {results[1]:.4f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9940 - loss: 0.1146
# Loss: 0.1363, Accuracy: 0.9883

# %%
# 繪製學習曲線
plt.figure()
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Learning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Learning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# 混淆矩陣繪製
def plot_confusion_matrix(y_true, y_pred, label_encoder, title):
    """
    繪製混淆矩陣，顯示數字映射標籤
    """
    cm = confusion_matrix(y_true, y_pred)
    numeric_labels = range(len(label_encoder.classes_))  # 使用數字標籤
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=numeric_labels, yticklabels=numeric_labels)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# 預測並繪製混淆矩陣
y_pred_screw = model.predict(X_test.reshape(X_test.shape[0], X_test.shape[1], 1)).argmax(axis=1)
plot_confusion_matrix(y_test_screws, y_pred_screw, le_screws, "Confusion Matrix - Model 21 - One-stage generlization")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# 儲存模型
model.save(f'{rootDir}\\階段3\\model\\VGG16_A8000_11.keras')
