# %% [markdown]
# ### 馬達論文研究
# ### 第五步 重新模型建立
# ### 馬達A 11000RPM
# ### CNN_VGG
# ### 10種工況

# %%
# 匯入所需函式庫
import os
import logging
import absl.logging
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler, label_binarize, LabelEncoder, RobustScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, Input, Concatenate, Add, Activation, GlobalAveragePooling1D, Multiply
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings("ignore")

# %%
# 資料準備與處理
def load_and_preprocess_data(base_dir, screws_list):
    datasets = []
    for screws in screws_list:
        file_path = os.path.join(base_dir, f'{screws}\\T3_Group_feature_data.csv')
        if os.path.exists(file_path):
            dataset = pd.read_csv(file_path)
            dataset['screws'] = screws
            datasets.append(dataset)
        else:
            print(f"檔案未找到: {file_path}")
    return datasets

# %%
# 新資料
def load_and_preprocess_newdata(base_dir, screws_list):
    datasets = []
    for screws in screws_list:
        file_path = os.path.join(base_dir, f'{screws}\\T3_Group_feature_data.csv')
        if os.path.exists(file_path):
            dataset = pd.read_csv(file_path)
            dataset['screws'] = screws
            datasets.append(dataset)
        else:
            print(f"檔案未找到: {file_path}")
    return datasets

# %%
# 加載資料
rootDir = os.getcwd()
myfeatureDirectory = f'{rootDir}\\階段3\\myfeature\\T3\\11000rpm'

screws_list = ['8screws', '1screws', '2screws', '3screws', '4screws']
datasets_T1 = load_and_preprocess_data(myfeatureDirectory, screws_list)

# %%
myfeatureDirectory2 = f'{rootDir}\\階段3\\myfeature\\T3\\11000rpm'

screws_list2 = ['5screws', '6screws', '7screws', '3_14screws', '4_146screws']
datasets_T2 = load_and_preprocess_newdata(myfeatureDirectory2, screws_list2)

# %%
# 合併資料
combined_data = pd.concat(datasets_T1 + datasets_T2, ignore_index=True)

# %%
# **手動定義標籤順序**
desired_order = ['8screws', '1screws', '2screws', '3screws', '4screws', '5screws', '6screws', '7screws', '3_14screws', '4_146screws']
label_mapping = {screw: idx for idx, screw in enumerate(desired_order)}
combined_data['screws'] = combined_data['screws'].map(label_mapping)

# %%
# 標籤編碼
le_screws = LabelEncoder()
combined_data['screws'] = le_screws.fit_transform(combined_data['screws'])

# %%
# 確認標籤映射是否正確
print("自訂 Label Mapping:")
for label, num in label_mapping.items():
    print(f"{label}: {num}")
# Out:
# 自訂 Label Mapping:
# 8screws: 0
# 1screws: 1
# 2screws: 2
# 3screws: 3
# 4screws: 4
# 5screws: 5
# 6screws: 6
# 7screws: 7
# 3_14screws: 8
# 4_146screws: 9

# %%
# 資料分割
X = combined_data.drop(['screws'], axis=1).values
y_screws = combined_data['screws'].values

# %%
# 劃分訓練與測試集
X_train, X_test, y_train_screws, y_test_screws = train_test_split(
    X, y_screws, test_size=0.2, random_state=42
)

# %%
# 標準化特徵
scaler = RobustScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# 建立 VGG16 模型
def build_vgg16_model(input_shape, num_classes):
    # 輸入層
    X_input = Input(shape=input_shape)

    # 第一層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X_input)

    # 第二層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    X = MaxPooling1D(pool_size=2, strides=2)(X)

    # 第三層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    
    # 第四層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    X = MaxPooling1D(pool_size=2, strides=2)(X)

    # 第五層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    
    # 第六層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)

    # 第七層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    X = MaxPooling1D(pool_size=2, strides=2)(X)

    # 第八層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    
    # 第九層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)

    # 第十層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    X = MaxPooling1D(pool_size=2, strides=2)(X)

    # 第十一層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    
    # 第十二層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)

    # 第十三層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    X = MaxPooling1D(pool_size=2, strides=2)(X)

    # 展平層
    X = Flatten()(X)

    # 第十四層全連接層
    X = Dense(64, activation='relu')(X)
    X = Dropout(0.3)(X)

    # 第十五層全連接層
    X = Dense(64, activation='relu')(X)
    X = Dropout(0.3)(X)

    # 第十六層全連接層
    output = Dense(num_classes, activation='softmax', name="Screw_Number_Output")(X)


    # 定義模型
    model = Model(inputs=X_input, outputs=output)
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss=["sparse_categorical_crossentropy"],
        metrics=["accuracy"]
    )
    return model

# %%
# 模型參數
num_screw_classes = len(np.unique(y_train_screws))

# %%
# 建立與訓練模型
vgg16_model = build_vgg16_model((X_train.shape[1], 1), num_screw_classes)
history = vgg16_model.fit(
    X_train.reshape(X_train.shape[0], X_train.shape[1], 1),
    y_train_screws,
    validation_data=(
        X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
        y_test_screws
    ),
    epochs=100,
    batch_size=32,
    callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
)
# Out:
# Epoch 1/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.1683 - loss: 2.2810 - val_accuracy: 0.4190 - val_loss: 1.6698
# Epoch 2/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4114 - loss: 1.6345 - val_accuracy: 0.7529 - val_loss: 0.8933
# Epoch 3/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6705 - loss: 0.9648 - val_accuracy: 0.9741 - val_loss: 0.2830
# Epoch 4/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8217 - loss: 0.5674 - val_accuracy: 0.9850 - val_loss: 0.0875
# Epoch 5/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8896 - loss: 0.3652 - val_accuracy: 0.9908 - val_loss: 0.0524
# Epoch 6/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9223 - loss: 0.2477 - val_accuracy: 0.9942 - val_loss: 0.0273
# Epoch 7/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9405 - loss: 0.1934 - val_accuracy: 0.9942 - val_loss: 0.0243
# Epoch 8/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9575 - loss: 0.1446 - val_accuracy: 0.9958 - val_loss: 0.0123
# Epoch 9/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9637 - loss: 0.1376 - val_accuracy: 0.9967 - val_loss: 0.0122
# Epoch 10/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9673 - loss: 0.1162 - val_accuracy: 0.9983 - val_loss: 0.0059
# Epoch 11/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9686 - loss: 0.1020 - val_accuracy: 0.9992 - val_loss: 0.0043
# Epoch 12/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9748 - loss: 0.0915 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 13/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9725 - loss: 0.0847 - val_accuracy: 0.9983 - val_loss: 0.0072
# Epoch 14/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9816 - loss: 0.0609 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 15/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9834 - loss: 0.0608 - val_accuracy: 0.9983 - val_loss: 0.0047
# Epoch 16/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9843 - loss: 0.0530 - val_accuracy: 1.0000 - val_loss: 5.3132e-04
# Epoch 17/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9837 - loss: 0.0587 - val_accuracy: 1.0000 - val_loss: 8.3545e-04
# Epoch 18/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9882 - loss: 0.0391 - val_accuracy: 0.9992 - val_loss: 0.0025
# Epoch 19/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9873 - loss: 0.0471 - val_accuracy: 0.9992 - val_loss: 0.0026
# Epoch 20/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9927 - loss: 0.0295 - val_accuracy: 0.9992 - val_loss: 0.0038
# Epoch 21/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9895 - loss: 0.0389 - val_accuracy: 1.0000 - val_loss: 3.6046e-04
# Epoch 22/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9898 - loss: 0.0293 - val_accuracy: 1.0000 - val_loss: 7.7667e-04
# Epoch 23/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9916 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 4.0414e-04
# Epoch 24/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9907 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 1.4524e-04
# Epoch 25/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9898 - loss: 0.0280 - val_accuracy: 1.0000 - val_loss: 6.8255e-05
# Epoch 26/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9913 - loss: 0.0309 - val_accuracy: 1.0000 - val_loss: 6.2638e-05
# Epoch 27/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9929 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 2.9096e-04
# Epoch 28/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9940 - loss: 0.0321 - val_accuracy: 1.0000 - val_loss: 2.6238e-04
# Epoch 29/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9952 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 2.1188e-05
# Epoch 30/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9918 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 2.4120e-05
# Epoch 31/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9931 - loss: 0.0182 - val_accuracy: 1.0000 - val_loss: 8.5938e-05
# Epoch 32/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9935 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 1.6955e-04
# Epoch 33/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9954 - loss: 0.0171 - val_accuracy: 1.0000 - val_loss: 5.3736e-05
# Epoch 34/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9947 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 4.7343e-04
# Epoch 35/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9952 - loss: 0.0182 - val_accuracy: 1.0000 - val_loss: 5.8733e-05
# Epoch 36/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9933 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 37/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9961 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 3.1100e-04
# Epoch 38/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9968 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 1.3576e-05
# Epoch 39/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9948 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 3.7641e-05
# Epoch 40/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9955 - loss: 0.0135 - val_accuracy: 0.9992 - val_loss: 0.0016
# Epoch 41/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9953 - loss: 0.0119 - val_accuracy: 1.0000 - val_loss: 3.8079e-05
# Epoch 42/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9959 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 2.5009e-04
# Epoch 43/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9986 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 2.9236e-05
# Epoch 44/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9974 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 1.0512e-05
# Epoch 45/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9970 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 4.7002e-05
# Epoch 46/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9987 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 2.2769e-04
# Epoch 47/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9959 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 4.4529e-05
# Epoch 48/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9972 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 7.5573e-06
# Epoch 49/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9971 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 1.2767e-04
# Epoch 50/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9966 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 1.3580e-04
# Epoch 51/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9933 - loss: 0.0187 - val_accuracy: 1.0000 - val_loss: 1.7298e-05
# Epoch 52/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9982 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 4.6396e-06
# Epoch 53/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9978 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 2.0555e-06
# Epoch 54/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 1.5163e-06
# Epoch 55/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9973 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 2.6334e-05
# Epoch 56/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9950 - loss: 0.0172 - val_accuracy: 0.9992 - val_loss: 0.0013
# Epoch 57/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9961 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 1.3001e-05
# Epoch 58/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9990 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 5.2501e-06
# Epoch 59/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9976 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 3.0474e-06
# Epoch 60/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9980 - loss: 0.0076 - val_accuracy: 0.9983 - val_loss: 0.0029
# Epoch 61/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9957 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 1.5551e-05
# Epoch 62/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9987 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 2.3338e-05
# Epoch 63/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9984 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 3.4859e-05
# Epoch 64/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9985 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 1.5088e-04

# %%
# 模型架構
vgg16_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 105, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 105, 32)        │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 105, 32)        │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 52, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 52, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 52, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 26, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 26, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 26, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 26, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 13, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 13, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 13, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 13, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 6, 32)          │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 6, 32)          │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_12 (Conv1D)              │ (None, 6, 32)          │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Screw_Number_Output (Dense)     │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 145,184 (567.13 KB)
#  Trainable params: 48,394 (189.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 96,790 (378.09 KB)

# %%
# 評估模型
results = vgg16_model.evaluate(
    X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
    y_test_screws
)
print(f"Screw Number Loss: {results[0]:.4f}, Screw Number Accuracy: {results[1]:.4f}")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.6322e-06
# Screw Number Loss: 0.0000, Screw Number Accuracy: 1.0000

# %%
# 繪製學習曲線
plt.figure()
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Screw Number Learning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Screw Number Learning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# 混淆矩陣繪製
def plot_confusion_matrix(y_true, y_pred, label_encoder, title):
    """
    繪製混淆矩陣，顯示數字映射標籤
    """
    cm = confusion_matrix(y_true, y_pred)
    numeric_labels = range(len(label_encoder.classes_))  # 使用數字標籤
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=numeric_labels, yticklabels=numeric_labels)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# 預測並繪製混淆矩陣
y_pred_screw = vgg16_model.predict(X_test.reshape(X_test.shape[0], X_test.shape[1], 1)).argmax(axis=1)
plot_confusion_matrix(y_test_screws, y_pred_screw, le_screws, "Confusion Matrix - Model 27 - New Fault Diagnosis Model")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %%
# # 定義 K 折數
# kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# # 儲存每次訓練的結果
# screw_number_accuracies = []

# # 交叉驗證
# fold_idx = 1
# for train_idx, test_idx in kfold.split(X):
#     # print(f"=== Fold {fold_idx} ===")
#     X_train, X_test = X[train_idx], X[test_idx]
#     y_train_screws, y_test_screws = y_screws[train_idx], y_screws[test_idx]

#     # 標準化特徵
#     scaler = RobustScaler()
#     X_train = scaler.fit_transform(X_train)
#     X_test = scaler.transform(X_test)

#     # 建立模型
#     kfold_model = build_vgg16_model((X_train.shape[1], 1), len(np.unique(y_screws)))

#     # 訓練模型
#     kfold_history = kfold_model.fit(
#         X_train.reshape(X_train.shape[0], X_train.shape[1], 1),
#         y_train_screws,
#         validation_data=(
#             X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
#             y_test_screws
#         ),
#         epochs=100,
#         batch_size=32,
#         verbose=0,
#         callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
#     )

#     # 評估模型
#     results = kfold_model.evaluate(
#         X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
#         y_test_screws,
#         verbose=0
#     )

#     screw_number_accuracies.append(results[1])  # 記錄準確率

#     # 顯示當前折的結果
#     print(f"Fold {fold_idx} Screws Model Accuracy: {results[1] * 100:.2f}%")
#     fold_idx += 1


# # 計算平均與標準差
# avg_screws_acc = np.mean(screw_number_accuracies) * 100
# std_screws_acc = np.std(screw_number_accuracies)


# # 總結結果
# print("\n=== Screws Model Results ===")
# print(f"使用 10-fold Cross Validation 之模型正確率平均值：{avg_screws_acc:.2f}%")
# print(f"使用 10-fold Cross Validation 之模型正確率標準差：{std_screws_acc:.2f}")
