# %% [markdown]
# ### 馬達論文研究
# ### 第三步 遷移式學習
# ### 馬達A 11000RPM
# ### CNN_VGG
# ### 單階段泛化

# %%
# 匯入所需函式庫
import os
import logging
import absl.logging
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler, label_binarize, LabelEncoder, RobustScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, Input, Concatenate, Add, Activation, GlobalAveragePooling1D, Multiply
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import warnings
from gpu_utils import device_scope
warnings.filterwarnings("ignore")

# %%
# 資料準備與處理
def load_and_preprocess_data(base_dir, screws_list):
    datasets = []
    for screws in screws_list:
        file_path = os.path.join(base_dir, f'T3\\11000rpm\\{screws}\\T3_Group_feature_data.csv')
        if os.path.exists(file_path):
            dataset = pd.read_csv(file_path)
            dataset['screws'] = screws
            datasets.append(dataset)
        else:
            print(f"檔案未找到: {file_path}")
    return datasets

# %%
# 加載資料
rootDir = os.getcwd()
modelDirectory = f'{rootDir}\\階段1\\model'
myfeatureDirectory = f'{rootDir}\\階段3\\myfeature'

screws_list = ['8screws', '1screws', '2screws', '3screws', '4screws']
datasets_T1 = load_and_preprocess_data(myfeatureDirectory, screws_list)

# %%
# 合併資料
combined_data = pd.concat(datasets_T1, ignore_index=True)

# %%
# **手動定義標籤順序**
desired_order = ['8screws', '1screws', '2screws', '3screws', '4screws']
label_mapping = {screw: idx for idx, screw in enumerate(desired_order)}
combined_data['screws'] = combined_data['screws'].map(label_mapping)

# %%
# 標籤編碼
le_screws = LabelEncoder()
combined_data['screws'] = le_screws.fit_transform(combined_data['screws'])

# %%
# 確認標籤映射是否正確
print("自訂 Label Mapping:")
for label, num in label_mapping.items():
    print(f"{label}: {num}")
# Out:
# 自訂 Label Mapping:
# 8screws: 0
# 1screws: 1
# 2screws: 2
# 3screws: 3
# 4screws: 4

# %%
# 資料分割
X = combined_data.drop(['screws'], axis=1).values
y_screws = combined_data['screws'].values

# %%
# 劃分訓練與測試集
X_train, X_test, y_train_screws, y_test_screws = train_test_split(
    X, y_screws, test_size=0.2, random_state=42
)

# %%
# 標準化特徵
scaler = RobustScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# 載入模型
model_path = f'{modelDirectory}\\VGG16_C8000.keras'

# 載入模型
model = load_model(model_path)

# 確認模型載入成功
print("模型已成功載入。")
# Out:
# 模型已成功載入。

# %%
# 計算需要凍結的層數（保留 50% 可訓練）
num_layers = len(model.layers)
train_layers_1 = int(num_layers * 0.5)  # 50% 可訓練
freeze_layers_1 = num_layers - train_layers_1  # 50% 凍結

# 凍結前 freeze_layers層
for layer in model.layers[:freeze_layers_1]:
    layer.trainable = False

# 確認層狀態
for i, layer in enumerate(model.layers):
    print(f"Model 2 - Layer {i}: {layer.name} | Trainable: {layer.trainable}")
# Out:
# Model 2 - Layer 0: input_layer | Trainable: False
# Model 2 - Layer 1: conv1d | Trainable: False
# Model 2 - Layer 2: conv1d_1 | Trainable: False
# Model 2 - Layer 3: max_pooling1d | Trainable: False
# Model 2 - Layer 4: conv1d_2 | Trainable: False
# Model 2 - Layer 5: conv1d_3 | Trainable: False
# Model 2 - Layer 6: max_pooling1d_1 | Trainable: False
# Model 2 - Layer 7: conv1d_4 | Trainable: False
# Model 2 - Layer 8: conv1d_5 | Trainable: False
# Model 2 - Layer 9: conv1d_6 | Trainable: False
# Model 2 - Layer 10: max_pooling1d_2 | Trainable: False
# Model 2 - Layer 11: conv1d_7 | Trainable: False
# Model 2 - Layer 12: conv1d_8 | Trainable: False
# Model 2 - Layer 13: conv1d_9 | Trainable: True
# Model 2 - Layer 14: max_pooling1d_3 | Trainable: True
# Model 2 - Layer 15: conv1d_10 | Trainable: True
# Model 2 - Layer 16: conv1d_11 | Trainable: True
# Model 2 - Layer 17: conv1d_12 | Trainable: True
# Model 2 - Layer 18: max_pooling1d_4 | Trainable: True
# Model 2 - Layer 19: flatten | Trainable: True
# Model 2 - Layer 20: dense | Trainable: True
# Model 2 - Layer 21: dropout | Trainable: True
# Model 2 - Layer 22: dense_1 | Trainable: True
# Model 2 - Layer 23: dropout_1 | Trainable: True
# Model 2 - Layer 24: Screw_Number_Output | Trainable: True

# %%
# 重新訓練模型
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=["sparse_categorical_crossentropy"],
    metrics=["accuracy"]
)

# %%
# 訓練模型
history = model.fit(
    X_train.reshape(X_train.shape[0], X_train.shape[1], 1),
    y_train_screws,
    validation_data=(
        X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
        y_test_screws
    ),
    epochs=100,
    batch_size=32,
    callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
)
# Out:
# Epoch 1/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1442 - loss: 5.4714 - val_accuracy: 0.4975 - val_loss: 1.5168
# Epoch 2/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3996 - loss: 1.6273 - val_accuracy: 0.5927 - val_loss: 1.0506
# Epoch 3/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5276 - loss: 1.1522 - val_accuracy: 0.7613 - val_loss: 0.8358
# Epoch 4/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6209 - loss: 0.9650 - val_accuracy: 0.8831 - val_loss: 0.6673
# Epoch 5/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7111 - loss: 0.7924 - val_accuracy: 0.9149 - val_loss: 0.5368
# Epoch 6/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7802 - loss: 0.6660 - val_accuracy: 0.9466 - val_loss: 0.4268
# Epoch 7/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8151 - loss: 0.5914 - val_accuracy: 0.9516 - val_loss: 0.3524
# Epoch 8/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8449 - loss: 0.4784 - val_accuracy: 0.9683 - val_loss: 0.2735
# Epoch 9/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8748 - loss: 0.4083 - val_accuracy: 0.9716 - val_loss: 0.2162
# Epoch 10/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8898 - loss: 0.3576 - val_accuracy: 0.9750 - val_loss: 0.1778
# Epoch 11/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9182 - loss: 0.2861 - val_accuracy: 0.9750 - val_loss: 0.1464
# Epoch 12/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9330 - loss: 0.2436 - val_accuracy: 0.9800 - val_loss: 0.1232
# Epoch 13/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9363 - loss: 0.2221 - val_accuracy: 0.9833 - val_loss: 0.1153
# Epoch 14/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9349 - loss: 0.2091 - val_accuracy: 0.9783 - val_loss: 0.0924
# Epoch 15/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9499 - loss: 0.1759 - val_accuracy: 0.9833 - val_loss: 0.0810
# Epoch 16/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9511 - loss: 0.1688 - val_accuracy: 0.9833 - val_loss: 0.0719
# Epoch 17/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9650 - loss: 0.1413 - val_accuracy: 0.9866 - val_loss: 0.0570
# Epoch 18/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9537 - loss: 0.1276 - val_accuracy: 0.9883 - val_loss: 0.0594
# Epoch 19/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9658 - loss: 0.1121 - val_accuracy: 0.9850 - val_loss: 0.0457
# Epoch 20/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9672 - loss: 0.1128 - val_accuracy: 0.9850 - val_loss: 0.0424
# Epoch 21/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9773 - loss: 0.0821 - val_accuracy: 0.9917 - val_loss: 0.0418
# Epoch 22/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9794 - loss: 0.0743 - val_accuracy: 0.9883 - val_loss: 0.0305
# Epoch 23/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9767 - loss: 0.0852 - val_accuracy: 0.9866 - val_loss: 0.0315
# Epoch 24/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9814 - loss: 0.0661 - val_accuracy: 0.9900 - val_loss: 0.0249
# Epoch 25/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9817 - loss: 0.0643 - val_accuracy: 0.9900 - val_loss: 0.0322
# Epoch 26/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9790 - loss: 0.0712 - val_accuracy: 0.9917 - val_loss: 0.0228
# Epoch 27/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9826 - loss: 0.0558 - val_accuracy: 0.9900 - val_loss: 0.0183
# Epoch 28/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9846 - loss: 0.0544 - val_accuracy: 0.9917 - val_loss: 0.0239
# Epoch 29/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9907 - loss: 0.0420 - val_accuracy: 0.9917 - val_loss: 0.0275
# Epoch 30/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9843 - loss: 0.0491 - val_accuracy: 0.9917 - val_loss: 0.0164
# Epoch 31/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9867 - loss: 0.0454 - val_accuracy: 0.9950 - val_loss: 0.0117
# Epoch 32/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9941 - loss: 0.0277 - val_accuracy: 0.9983 - val_loss: 0.0134
# Epoch 33/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9897 - loss: 0.0382 - val_accuracy: 0.9983 - val_loss: 0.0096
# Epoch 34/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.0291 - val_accuracy: 0.9933 - val_loss: 0.0164
# Epoch 35/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9879 - loss: 0.0349 - val_accuracy: 0.9983 - val_loss: 0.0074
# Epoch 36/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9946 - loss: 0.0244 - val_accuracy: 0.9933 - val_loss: 0.0124
# Epoch 37/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9919 - loss: 0.0274 - val_accuracy: 0.9983 - val_loss: 0.0147
# Epoch 38/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9907 - loss: 0.0276 - val_accuracy: 0.9933 - val_loss: 0.0243
# Epoch 39/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9969 - loss: 0.0205 - val_accuracy: 0.9967 - val_loss: 0.0182
# Epoch 40/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9958 - loss: 0.0194 - val_accuracy: 0.9917 - val_loss: 0.0236
# Epoch 41/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9912 - loss: 0.0304 - val_accuracy: 0.9983 - val_loss: 0.0138
# Epoch 42/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9936 - loss: 0.0243 - val_accuracy: 0.9967 - val_loss: 0.0137
# Epoch 43/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9980 - loss: 0.0144 - val_accuracy: 0.9967 - val_loss: 0.0085
# Epoch 44/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9982 - loss: 0.0138 - val_accuracy: 0.9967 - val_loss: 0.0127
# Epoch 45/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9956 - loss: 0.0194 - val_accuracy: 0.9967 - val_loss: 0.0162

# %%
# 清除
tf.keras.backend.clear_session()
# Out:
# WARNING:tensorflow:From c:\Users\IMSL\anaconda3\envs\motor\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
# 模型架構
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 105, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 105, 32)        │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 105, 32)        │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 52, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 52, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 52, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 26, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 26, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 26, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 26, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 13, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 13, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 13, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 13, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 6, 32)          │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 6, 32)          │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_12 (Conv1D)              │ (None, 6, 32)          │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Screw_Number_Output (Dense)     │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,289 (368.32 KB)
#  Trainable params: 23,109 (90.27 KB)
#  Non-trainable params: 24,960 (97.50 KB)
#  Optimizer params: 46,220 (180.55 KB)

# %%
# 評估模型
results = model.evaluate(
    X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
    y_test_screws
)
print(f"Loss: {results[0]:.4f}, Accuracy: {results[1]:.4f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0058
# Loss: 0.0074, Accuracy: 0.9983

# %%
# 繪製學習曲線
plt.figure()
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Learning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Learning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# 混淆矩陣繪製
def plot_confusion_matrix(y_true, y_pred, label_encoder, title):
    """
    繪製混淆矩陣，顯示數字映射標籤
    """
    cm = confusion_matrix(y_true, y_pred)
    numeric_labels = range(len(label_encoder.classes_))  # 使用數字標籤
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=numeric_labels, yticklabels=numeric_labels)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# 預測並繪製混淆矩陣
y_pred_screw = model.predict(X_test.reshape(X_test.shape[0], X_test.shape[1], 1)).argmax(axis=1)
plot_confusion_matrix(y_test_screws, y_pred_screw, le_screws, "Confusion Matrix - Model 27 - One-stage generlization")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step

# %%
# 儲存模型
model.save(f'{rootDir}\\階段3\\model\\VGG16_A11000_1.keras')
