# %% [markdown]
# ### 馬達論文研究
# ### 第五步 重新模型建立
# ### 馬達C 8000RPM
# ### CNN_VGG
# ### 10種工況

# %%
# 匯入所需函式庫
import os
import logging
import absl.logging
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler, label_binarize, LabelEncoder, RobustScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, Input, Concatenate, Add, Activation, GlobalAveragePooling1D, Multiply
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import warnings
from gpu_utils import device_scope, DEVICE
warnings.filterwarnings("ignore")

# %%
# 資料準備與處理
def load_and_preprocess_data(base_dir, screws_list):
    datasets = []
    for screws in screws_list:
        file_path = os.path.join(base_dir, f'{screws}\\T1_Group_feature_data.csv')
        if os.path.exists(file_path):
            dataset = pd.read_csv(file_path)
            dataset['screws'] = screws
            datasets.append(dataset)
        else:
            print(f"檔案未找到: {file_path}")
    return datasets

# %%
# 新資料
def load_and_preprocess_newdata(base_dir, screws_list):
    datasets = []
    for screws in screws_list:
        file_path = os.path.join(base_dir, f'{screws}\\T1_Group_feature_data.csv')
        if os.path.exists(file_path):
            dataset = pd.read_csv(file_path)
            dataset['screws'] = screws
            datasets.append(dataset)
        else:
            print(f"檔案未找到: {file_path}")
    return datasets

# %%
# 加載資料
rootDir = os.getcwd()
myfeatureDirectory = f'{rootDir}\\階段1\\myfeature\\T1\\8000rpm'

screws_list = ['8screws', '1screws', '2screws', '3screws', '4screws']
datasets_T1 = load_and_preprocess_data(myfeatureDirectory, screws_list)

# %%
myfeatureDirectory2 = f'{rootDir}\\階段1\\myfeature\\T1\\8000rpm'

screws_list2 = ['5screws', '6screws', '7screws', '3_14screws', '4_146screws']
datasets_T2 = load_and_preprocess_newdata(myfeatureDirectory2, screws_list2)

# %%
# 合併資料
combined_data = pd.concat(datasets_T1 + datasets_T2, ignore_index=True)

# %%
# **手動定義標籤順序**
desired_order = ['8screws', '1screws', '2screws', '3screws', '4screws', '5screws', '6screws', '7screws', '3_14screws', '4_146screws']
label_mapping = {screw: idx for idx, screw in enumerate(desired_order)}
combined_data['screws'] = combined_data['screws'].map(label_mapping)

# %%
# 標籤編碼
le_screws = LabelEncoder()
combined_data['screws'] = le_screws.fit_transform(combined_data['screws'])

# %%
# 確認標籤映射是否正確
print("自訂 Label Mapping:")
for label, num in label_mapping.items():
    print(f"{label}: {num}")
# Out:
# 自訂 Label Mapping:
# 8screws: 0
# 1screws: 1
# 2screws: 2
# 3screws: 3
# 4screws: 4
# 5screws: 5
# 6screws: 6
# 7screws: 7
# 3_14screws: 8
# 4_146screws: 9

# %%
# 資料分割
X = combined_data.drop(['screws'], axis=1).values
y_screws = combined_data['screws'].values

# %%
# 劃分訓練與測試集
X_train, X_test, y_train_screws, y_test_screws = train_test_split(
    X, y_screws, test_size=0.2, random_state=42
)

# %%
# 標準化特徵
scaler = RobustScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# 建立 VGG16 模型
def build_vgg16_model(input_shape, num_classes):
    # 輸入層
    X_input = Input(shape=input_shape)

    # 第一層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X_input)

    # 第二層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    X = MaxPooling1D(pool_size=2, strides=2)(X)

    # 第三層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    
    # 第四層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    X = MaxPooling1D(pool_size=2, strides=2)(X)

    # 第五層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    
    # 第六層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)

    # 第七層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    X = MaxPooling1D(pool_size=2, strides=2)(X)

    # 第八層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    
    # 第九層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)

    # 第十層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    X = MaxPooling1D(pool_size=2, strides=2)(X)

    # 第十一層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    
    # 第十二層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)

    # 第十三層卷積
    X = Conv1D(32, kernel_size=3, activation='relu', padding='same')(X)
    X = MaxPooling1D(pool_size=2, strides=2)(X)

    # 展平層
    X = Flatten()(X)

    # 第十四層全連接層
    X = Dense(64, activation='relu')(X)
    X = Dropout(0.3)(X)

    # 第十五層全連接層
    X = Dense(64, activation='relu')(X)
    X = Dropout(0.3)(X)

    # 第十六層全連接層
    output = Dense(num_classes, activation='softmax', name="Screw_Number_Output")(X)


    # 定義模型
    model = Model(inputs=X_input, outputs=output)
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss=["sparse_categorical_crossentropy"],
        metrics=["accuracy"]
    )
    return model

# %%
# 模型參數
num_screw_classes = len(np.unique(y_train_screws))

# %%
print(f"[Training] Device: {DEVICE}")
with device_scope():
    # 建立與訓練模型
    vgg16_model = build_vgg16_model((X_train.shape[1], 1), num_screw_classes)
    history = vgg16_model.fit(
        X_train.reshape(X_train.shape[0], X_train.shape[1], 1),
        y_train_screws,
        validation_data=(
            X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
            y_test_screws
        ),
        epochs=100,
        batch_size=32,
        callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
    )
# Out:
# Epoch 1/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1373 - loss: 2.2392 - val_accuracy: 0.2838 - val_loss: 1.7433
# Epoch 2/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3584 - loss: 1.6855 - val_accuracy: 0.7627 - val_loss: 0.9130
# Epoch 3/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6166 - loss: 1.0685 - val_accuracy: 0.9324 - val_loss: 0.3993
# Epoch 4/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7677 - loss: 0.6716 - val_accuracy: 0.9637 - val_loss: 0.1991
# Epoch 5/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8544 - loss: 0.4617 - val_accuracy: 0.9814 - val_loss: 0.0923
# Epoch 6/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9089 - loss: 0.2844 - val_accuracy: 0.9890 - val_loss: 0.0604
# Epoch 7/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9274 - loss: 0.2288 - val_accuracy: 0.9890 - val_loss: 0.0362
# Epoch 8/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9495 - loss: 0.1686 - val_accuracy: 0.9907 - val_loss: 0.0306
# Epoch 9/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9560 - loss: 0.1502 - val_accuracy: 0.9949 - val_loss: 0.0207
# Epoch 10/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9577 - loss: 0.1526 - val_accuracy: 0.9932 - val_loss: 0.0175
# Epoch 11/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9598 - loss: 0.1165 - val_accuracy: 0.9966 - val_loss: 0.0112
# Epoch 12/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9706 - loss: 0.1167 - val_accuracy: 0.9958 - val_loss: 0.0119
# Epoch 13/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9706 - loss: 0.1022 - val_accuracy: 0.9992 - val_loss: 0.0080
# Epoch 14/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9727 - loss: 0.1026 - val_accuracy: 0.9983 - val_loss: 0.0078
# Epoch 15/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9834 - loss: 0.0546 - val_accuracy: 0.9992 - val_loss: 0.0047
# Epoch 16/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9829 - loss: 0.0613 - val_accuracy: 0.9966 - val_loss: 0.0087
# Epoch 17/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9829 - loss: 0.0674 - val_accuracy: 0.9983 - val_loss: 0.0065
# Epoch 18/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9827 - loss: 0.0542 - val_accuracy: 0.9983 - val_loss: 0.0047
# Epoch 19/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9884 - loss: 0.0494 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 20/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9791 - loss: 0.0610 - val_accuracy: 0.9992 - val_loss: 0.0019
# Epoch 21/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9847 - loss: 0.0448 - val_accuracy: 0.9992 - val_loss: 0.0034
# Epoch 22/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9882 - loss: 0.0390 - val_accuracy: 0.9992 - val_loss: 0.0034
# Epoch 23/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9883 - loss: 0.0359 - val_accuracy: 0.9992 - val_loss: 0.0031
# Epoch 24/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9897 - loss: 0.0357 - val_accuracy: 0.9983 - val_loss: 0.0023
# Epoch 25/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9925 - loss: 0.0201 - val_accuracy: 0.9983 - val_loss: 0.0028
# Epoch 26/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9926 - loss: 0.0297 - val_accuracy: 0.9983 - val_loss: 0.0028
# Epoch 27/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9913 - loss: 0.0277 - val_accuracy: 1.0000 - val_loss: 7.5943e-04
# Epoch 28/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9922 - loss: 0.0272 - val_accuracy: 0.9992 - val_loss: 0.0016
# Epoch 29/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9923 - loss: 0.0226 - val_accuracy: 0.9992 - val_loss: 0.0023
# Epoch 30/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9897 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 4.3830e-04
# Epoch 31/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9922 - loss: 0.0289 - val_accuracy: 0.9966 - val_loss: 0.0110
# Epoch 32/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9938 - loss: 0.0193 - val_accuracy: 0.9983 - val_loss: 0.0056
# Epoch 33/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9939 - loss: 0.0235 - val_accuracy: 0.9992 - val_loss: 0.0011
# Epoch 34/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9945 - loss: 0.0167 - val_accuracy: 1.0000 - val_loss: 3.8983e-04
# Epoch 35/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9958 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 4.4394e-04
# Epoch 36/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9946 - loss: 0.0224 - val_accuracy: 0.9992 - val_loss: 0.0028
# Epoch 37/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9968 - loss: 0.0185 - val_accuracy: 1.0000 - val_loss: 7.8047e-04
# Epoch 38/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9938 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 6.0466e-04
# Epoch 39/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9965 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 2.6820e-04
# Epoch 40/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9950 - loss: 0.0173 - val_accuracy: 1.0000 - val_loss: 7.4428e-04
# Epoch 41/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9899 - loss: 0.0333 - val_accuracy: 1.0000 - val_loss: 3.3457e-04
# Epoch 42/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9963 - loss: 0.0175 - val_accuracy: 0.9992 - val_loss: 7.4378e-04
# Epoch 43/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9982 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 2.3238e-04
# Epoch 44/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9964 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 6.0953e-04
# Epoch 45/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9950 - loss: 0.0185 - val_accuracy: 1.0000 - val_loss: 5.4487e-04
# Epoch 46/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9962 - loss: 0.0127 - val_accuracy: 1.0000 - val_loss: 2.3295e-04
# Epoch 47/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9978 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 1.6779e-04
# Epoch 48/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9952 - loss: 0.0159 - val_accuracy: 1.0000 - val_loss: 4.7329e-04
# Epoch 49/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9952 - loss: 0.0171 - val_accuracy: 0.9992 - val_loss: 8.5627e-04
# Epoch 50/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9974 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 4.3401e-04
# Epoch 51/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9959 - loss: 0.0130 - val_accuracy: 0.9992 - val_loss: 0.0010
# Epoch 52/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9986 - loss: 0.0058 - val_accuracy: 0.9992 - val_loss: 8.6160e-04
# Epoch 53/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9980 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 1.4834e-04
# Epoch 54/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9976 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 2.9698e-04
# Epoch 55/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9988 - loss: 0.0070 - val_accuracy: 0.9992 - val_loss: 0.0013
# Epoch 56/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9953 - loss: 0.0104 - val_accuracy: 0.9992 - val_loss: 0.0014
# Epoch 57/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9966 - loss: 0.0091 - val_accuracy: 0.9992 - val_loss: 0.0021
# Epoch 58/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9969 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 1.2484e-04
# Epoch 59/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9989 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 3.5972e-04
# Epoch 60/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9975 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 2.2690e-04
# Epoch 61/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9958 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 2.1061e-04
# Epoch 62/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9959 - loss: 0.0118 - val_accuracy: 0.9992 - val_loss: 7.2122e-04
# Epoch 63/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9984 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 3.2253e-04
# Epoch 64/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9987 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 2.2410e-04
# Epoch 65/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9982 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 1.9136e-04
# Epoch 66/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 1.9376e-04
# Epoch 67/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 4.6213e-05
# Epoch 68/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9987 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 1.7516e-04
# Epoch 69/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9958 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 7.2890e-05
# Epoch 70/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9979 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 3.2958e-05
# Epoch 71/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9976 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 4.3271e-05
# Epoch 72/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9986 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 1.2926e-04
# Epoch 73/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9987 - loss: 0.0077 - val_accuracy: 0.9992 - val_loss: 0.0013
# Epoch 74/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9990 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 5.2613e-05
# Epoch 75/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9974 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 3.5380e-05
# Epoch 76/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9987 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 6.5922e-06
# Epoch 77/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9989 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 1.1226e-06
# Epoch 78/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 8.3816e-07
# Epoch 79/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9981 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 4.1398e-06
# Epoch 80/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9996 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 2.8187e-06
# Epoch 81/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9998 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 6.8585e-05
# Epoch 82/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9994 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 8.2041e-07
# Epoch 83/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9995 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 7.3447e-07
# Epoch 84/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9993 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 1.6950e-05
# Epoch 85/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9974 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 3.3746e-05
# Epoch 86/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 3.1012e-05
# Epoch 87/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9978 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 5.3990e-04
# Epoch 88/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9971 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 6.6076e-06
# Epoch 89/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9988 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 6.2844e-06
# Epoch 90/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9991 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 4.5365e-06
# Epoch 91/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 9.7808e-04 - val_accuracy: 1.0000 - val_loss: 3.3294e-06
# Epoch 92/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9988 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 1.7617e-05
# Epoch 93/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9990 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 1.0079e-05

# %%
# 模型架構
vgg16_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 105, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 105, 32)        │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 105, 32)        │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 52, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 52, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 52, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 26, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 26, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 26, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 26, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 13, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 13, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 13, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 13, 32)         │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 6, 32)          │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 6, 32)          │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_12 (Conv1D)              │ (None, 6, 32)          │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Screw_Number_Output (Dense)     │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 145,184 (567.13 KB)
#  Trainable params: 48,394 (189.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 96,790 (378.09 KB)

# %%
# 評估模型
results = vgg16_model.evaluate(
    X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
    y_test_screws
)
print(f"Screw Number Loss: {results[0]:.4f}, Screw Number Accuracy: {results[1]:.4f}")
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.1491e-07
# Screw Number Loss: 0.0000, Screw Number Accuracy: 1.0000

# %%
# 繪製學習曲線
plt.figure()
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Screw Number Learning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Screw Number Learning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# 混淆矩陣繪製
def plot_confusion_matrix(y_true, y_pred, label_encoder, title):
    """
    繪製混淆矩陣，顯示數字映射標籤
    """
    cm = confusion_matrix(y_true, y_pred)
    numeric_labels = range(len(label_encoder.classes_))  # 使用數字標籤
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=numeric_labels, yticklabels=numeric_labels)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# 預測並繪製混淆矩陣
y_pred_screw = vgg16_model.predict(X_test.reshape(X_test.shape[0], X_test.shape[1], 1)).argmax(axis=1)
plot_confusion_matrix(y_test_screws, y_pred_screw, le_screws, "Confusion Matrix - Model 3 - New Fault Diagnosis Model")
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
print(f"[Training] Device: {DEVICE}")
with device_scope():
    # # 定義 K 折數
    # kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    
    # # 儲存每次訓練的結果
    # screw_number_accuracies = []
    
    # # 交叉驗證
    # fold_idx = 1
    # for train_idx, test_idx in kfold.split(X):
    #     # print(f"=== Fold {fold_idx} ===")
    #     X_train, X_test = X[train_idx], X[test_idx]
    #     y_train_screws, y_test_screws = y_screws[train_idx], y_screws[test_idx]
    
    #     # 標準化特徵
    #     scaler = RobustScaler()
    #     X_train = scaler.fit_transform(X_train)
    #     X_test = scaler.transform(X_test)
    
    #     # 建立模型
    #     kfold_model = build_vgg16_model((X_train.shape[1], 1), len(np.unique(y_screws)))
    
    #     # 訓練模型
    #     kfold_history = kfold_model.fit(
    #         X_train.reshape(X_train.shape[0], X_train.shape[1], 1),
    #         y_train_screws,
    #         validation_data=(
    #             X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
    #             y_test_screws
    #         ),
    #         epochs=100,
    #         batch_size=32,
    #         verbose=0,
    #         callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
    #     )
    
    #     # 評估模型
    #     results = kfold_model.evaluate(
    #         X_test.reshape(X_test.shape[0], X_test.shape[1], 1),
    #         y_test_screws,
    #         verbose=0
    #     )
    
    #     screw_number_accuracies.append(results[1])  # 記錄準確率
    
    #     # 顯示當前折的結果
    #     print(f"Fold {fold_idx} Screws Model Accuracy: {results[1] * 100:.2f}%")
    #     fold_idx += 1
    
    
    # # 計算平均與標準差
    # avg_screws_acc = np.mean(screw_number_accuracies) * 100
    # std_screws_acc = np.std(screw_number_accuracies)
    
    
    # # 總結結果
    # print("\n=== Screws Model Results ===")
    # print(f"使用 10-fold Cross Validation 之模型正確率平均值：{avg_screws_acc:.2f}%")
    # print(f"使用 10-fold Cross Validation 之模型正確率標準差：{std_screws_acc:.2f}")
